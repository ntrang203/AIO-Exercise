# %%
# !mkdir data/

# %%
# !gdown  1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu -O data/
# !gdown  15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf -O data/
# !gdown  1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq -O data/
# !gdown  1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu
# To: /content/data/landmark_val.csv
# 100% 369k/369k [00:00<00:00, 5.34MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf
# To: /content/data/landmark_train.csv
# 100% 1.28M/1.28M [00:00<00:00, 13.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq
# To: /content/data/landmark_test.csv
# 100% 320k/320k [00:00<00:00, 5.03MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw
# To: /content/hand_gesture.yaml
# 100% 120/120 [00:00<00:00, 518kB/s]

# %%
# !pip install mediapipe==0.10.18
# Out:
# Collecting mediapipe==0.10.18
#   Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (3.8.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.25.5)
# Collecting sounddevice>=0.4.4 (from mediapipe==0.10.18)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe==0.10.18) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.18) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.18) (1.16.0)
# Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 45.8 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.18 sounddevice-0.5.1

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.1+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 17.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.9 torchmetrics-1.6.0

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")

        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p =0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p =0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p =0.6),
            nn.Linear(128, len(list_label)),
        )
    def forward(self, x):
        x = self.flatten(x)
        x = self.linear_relu_stack(x)
        return x

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data

            optimizer.zero_grad()

            preds = model(inputs)

            loss = loss_function(preds, labels)
            loss.backward()
            optimizer.step()


            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break




    model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=40, shuffle=True)


valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30, min_delta=0.01)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.22178606688976288, val:0.2935153543949127
# LOSS train 1.607748343394353 valid 1.5896194577217102
# Training vs. Validation Loss {'Training': 1.607748343394353, 'Validation': 1.5896194577217102} 1
# Training vs. Validation accuracy {'Training': 0.22178606688976288, 'Validation': 0.2935153543949127} 1
# Epoch 1:
# Accuracy train:0.29440629482269287, val:0.3890784978866577
# LOSS train 1.5816469971950238 valid 1.5687578717867534
# Training vs. Validation Loss {'Training': 1.5816469971950238, 'Validation': 1.5687578717867534} 2
# Training vs. Validation accuracy {'Training': 0.29440629482269287, 'Validation': 0.3890784978866577} 2
# Epoch 2:
# Accuracy train:0.35132482647895813, val:0.467576801776886
# LOSS train 1.562935104736915 valid 1.5487923224767048
# Training vs. Validation Loss {'Training': 1.562935104736915, 'Validation': 1.5487923224767048} 3
# Training vs. Validation accuracy {'Training': 0.35132482647895813, 'Validation': 0.467576801776886} 3
# Epoch 3:
# Accuracy train:0.4367026388645172, val:0.4778156876564026
# LOSS train 1.524614421220926 valid 1.5082587401072185
# Training vs. Validation Loss {'Training': 1.524614421220926, 'Validation': 1.5082587401072185} 4
# Training vs. Validation accuracy {'Training': 0.4367026388645172, 'Validation': 0.4778156876564026} 4
# Epoch 4:
# Accuracy train:0.482826292514801, val:0.4402730464935303
# LOSS train 1.4645841809419484 valid 1.441035230954488
# Training vs. Validation Loss {'Training': 1.4645841809419484, 'Validation': 1.441035230954488} 5
# Training vs. Validation accuracy {'Training': 0.482826292514801, 'Validation': 0.4402730464935303} 5
# Epoch 5:
# Accuracy train:0.490677148103714, val:0.3686006963253021
# LOSS train 1.3795300951370826 valid 1.3327186405658722
# Training vs. Validation Loss {'Training': 1.3795300951370826, 'Validation': 1.3327186405658722} 6
# Training vs. Validation accuracy {'Training': 0.490677148103714, 'Validation': 0.3686006963253021} 6
# Epoch 6:
# Accuracy train:0.500490665435791, val:0.3890784978866577
# LOSS train 1.2467798682359548 valid 1.2274202307065327
# Training vs. Validation Loss {'Training': 1.2467798682359548, 'Validation': 1.2274202307065327} 7
# Training vs. Validation accuracy {'Training': 0.500490665435791, 'Validation': 0.3890784978866577} 7
# Epoch 7:
# Accuracy train:0.5230618119239807, val:0.44368600845336914
# LOSS train 1.1126685027892773 valid 1.0915795763333638
# Training vs. Validation Loss {'Training': 1.1126685027892773, 'Validation': 1.0915795763333638} 8
# Training vs. Validation accuracy {'Training': 0.5230618119239807, 'Validation': 0.44368600845336914} 8
# Epoch 8:
# Accuracy train:0.5574092268943787, val:0.4778156876564026
# LOSS train 0.9953700166482192 valid 0.9775685146450996
# Training vs. Validation Loss {'Training': 0.9953700166482192, 'Validation': 0.9775685146450996} 9
# Training vs. Validation accuracy {'Training': 0.5574092268943787, 'Validation': 0.4778156876564026} 9
# Epoch 9:
# Accuracy train:0.6064769625663757, val:0.5836177468299866
# LOSS train 0.9031893886052645 valid 0.8909471345444521
# Training vs. Validation Loss {'Training': 0.9031893886052645, 'Validation': 0.8909471345444521} 10
# Training vs. Validation accuracy {'Training': 0.6064769625663757, 'Validation': 0.5836177468299866} 10
# Epoch 10:
# Accuracy train:0.7124632000923157, val:0.9078498482704163
# LOSS train 0.8240488446675814 valid 0.7820647812138001
# Training vs. Validation Loss {'Training': 0.8240488446675814, 'Validation': 0.7820647812138001} 11
# Training vs. Validation accuracy {'Training': 0.7124632000923157, 'Validation': 0.9078498482704163} 11
# Epoch 11:
# Accuracy train:0.7791953086853027, val:0.8634812235832214
# LOSS train 0.7310234720890338 valid 0.6893616995463768
# Training vs. Validation Loss {'Training': 0.7310234720890338, 'Validation': 0.6893616995463768} 12
# Training vs. Validation accuracy {'Training': 0.7791953086853027, 'Validation': 0.8634812235832214} 12
# Epoch 12:
# Accuracy train:0.8586849570274353, val:0.9556313753128052
# LOSS train 0.6255970001220703 valid 0.5888867763181528
# Training vs. Validation Loss {'Training': 0.6255970001220703, 'Validation': 0.5888867763181528} 13
# Training vs. Validation accuracy {'Training': 0.8586849570274353, 'Validation': 0.9556313753128052} 13
# Epoch 13:
# Accuracy train:0.8851815462112427, val:0.9249146580696106
# LOSS train 0.539393384869282 valid 0.48838373956580955
# Training vs. Validation Loss {'Training': 0.539393384869282, 'Validation': 0.48838373956580955} 14
# Training vs. Validation accuracy {'Training': 0.8851815462112427, 'Validation': 0.9249146580696106} 14
# Epoch 14:
# Accuracy train:0.8910696506500244, val:0.9317406415939331
# LOSS train 0.4644994162596189 valid 0.4062516416112582
# Training vs. Validation Loss {'Training': 0.4644994162596189, 'Validation': 0.4062516416112582} 15
# Training vs. Validation accuracy {'Training': 0.8910696506500244, 'Validation': 0.9317406415939331} 15
# Epoch 15:
# Accuracy train:0.9214916825294495, val:0.9317406415939331
# LOSS train 0.37001886046849763 valid 0.3173776005084316
# Training vs. Validation Loss {'Training': 0.37001886046849763, 'Validation': 0.3173776005084316} 16
# Training vs. Validation accuracy {'Training': 0.9214916825294495, 'Validation': 0.9317406415939331} 16
# Epoch 16:
# Accuracy train:0.9263984560966492, val:0.9897611141204834
# LOSS train 0.31379543302150875 valid 0.23924921352105835
# Training vs. Validation Loss {'Training': 0.31379543302150875, 'Validation': 0.23924921352105835} 17
# Training vs. Validation accuracy {'Training': 0.9263984560966492, 'Validation': 0.9897611141204834} 17
# Epoch 17:
# Accuracy train:0.9568204283714294, val:0.9863481521606445
# LOSS train 0.24351663772876447 valid 0.16789164122504494
# Training vs. Validation Loss {'Training': 0.24351663772876447, 'Validation': 0.16789164122504494} 18
# Training vs. Validation accuracy {'Training': 0.9568204283714294, 'Validation': 0.9863481521606445} 18
# Epoch 18:
# Accuracy train:0.9695780277252197, val:0.9931740760803223
# LOSS train 0.21039552012315163 valid 0.10895683247751246
# Training vs. Validation Loss {'Training': 0.21039552012315163, 'Validation': 0.10895683247751246} 19
# Training vs. Validation accuracy {'Training': 0.9695780277252197, 'Validation': 0.9931740760803223} 19
# Epoch 19:
# Accuracy train:0.9715407490730286, val:0.979522168636322
# LOSS train 0.17053766863850447 valid 0.08477089845109731
# Training vs. Validation Loss {'Training': 0.17053766863850447, 'Validation': 0.08477089845109731} 20
# Training vs. Validation accuracy {'Training': 0.9715407490730286, 'Validation': 0.979522168636322} 20
# Epoch 20:
# Accuracy train:0.9636898636817932, val:0.9897611141204834
# LOSS train 0.15311568860824293 valid 0.05955292596869791
# Training vs. Validation Loss {'Training': 0.15311568860824293, 'Validation': 0.05955292596869791} 21
# Training vs. Validation accuracy {'Training': 0.9636898636817932, 'Validation': 0.9897611141204834} 21
# Epoch 21:
# Accuracy train:0.981354296207428, val:0.9829351305961609
# LOSS train 0.1228436164271373 valid 0.05352956310768301
# Training vs. Validation Loss {'Training': 0.1228436164271373, 'Validation': 0.05352956310768301} 22
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9829351305961609} 22
# Epoch 22:
# Accuracy train:0.9725220799446106, val:0.9897611141204834
# LOSS train 0.11939517379953311 valid 0.042111496188833066
# Training vs. Validation Loss {'Training': 0.11939517379953311, 'Validation': 0.042111496188833066} 23
# Training vs. Validation accuracy {'Training': 0.9725220799446106, 'Validation': 0.9897611141204834} 23
# Epoch 23:
# Accuracy train:0.9744848012924194, val:0.9897611141204834
# LOSS train 0.10388226979053937 valid 0.035217740485677496
# Training vs. Validation Loss {'Training': 0.10388226979053937, 'Validation': 0.035217740485677496} 24
# Training vs. Validation accuracy {'Training': 0.9744848012924194, 'Validation': 0.9897611141204834} 24
# Epoch 24:
# Accuracy train:0.981354296207428, val:0.9897611141204834
# LOSS train 0.0926097112063032 valid 0.03394426770197848
# Training vs. Validation Loss {'Training': 0.0926097112063032, 'Validation': 0.03394426770197848} 25
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9897611141204834} 25
# Epoch 25:
# Accuracy train:0.983316957950592, val:0.9829351305961609
# LOSS train 0.09458210734793773 valid 0.04061750924544564
# Training vs. Validation Loss {'Training': 0.09458210734793773, 'Validation': 0.04061750924544564} 26
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9829351305961609} 26
# Epoch 26:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.09502855057899769 valid 0.026717948479927145
# Training vs. Validation Loss {'Training': 0.09502855057899769, 'Validation': 0.026717948479927145} 27
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 27
# Epoch 27:
# Accuracy train:0.98233562707901, val:0.9931740760803223
# LOSS train 0.07241866264778835 valid 0.029984571500487316
# Training vs. Validation Loss {'Training': 0.07241866264778835, 'Validation': 0.029984571500487316} 28
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9931740760803223} 28
# Epoch 28:
# Accuracy train:0.981354296207428, val:0.9931740760803223
# LOSS train 0.07390513120648953 valid 0.026913154424012948
# Training vs. Validation Loss {'Training': 0.07390513120648953, 'Validation': 0.026913154424012948} 29
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9931740760803223} 29
# Epoch 29:
# Accuracy train:0.9901864528656006, val:0.9863481521606445
# LOSS train 0.06789011404348108 valid 0.030361263241502456
# Training vs. Validation Loss {'Training': 0.06789011404348108, 'Validation': 0.030361263241502456} 30
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9863481521606445} 30
# Epoch 30:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.07646353417434372 valid 0.029660767599125393
# Training vs. Validation Loss {'Training': 0.07646353417434372, 'Validation': 0.029660767599125393} 31
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 31
# Epoch 31:
# Accuracy train:0.9842983484268188, val:0.9931740760803223
# LOSS train 0.05853822329439796 valid 0.02407847591045235
# Training vs. Validation Loss {'Training': 0.05853822329439796, 'Validation': 0.02407847591045235} 32
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9931740760803223} 32
# Epoch 32:
# Accuracy train:0.9803729057312012, val:0.9931740760803223
# LOSS train 0.06813884909766224 valid 0.023954084166083096
# Training vs. Validation Loss {'Training': 0.06813884909766224, 'Validation': 0.023954084166083096} 33
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9931740760803223} 33
# Epoch 33:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.05359106725798203 valid 0.024353295708351652
# Training vs. Validation Loss {'Training': 0.05359106725798203, 'Validation': 0.024353295708351652} 34
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 34
# Epoch 34:
# Accuracy train:0.98233562707901, val:0.9931740760803223
# LOSS train 0.05261827070409289 valid 0.025465560997569508
# Training vs. Validation Loss {'Training': 0.05261827070409289, 'Validation': 0.025465560997569508} 35
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9931740760803223} 35
# Epoch 35:
# Accuracy train:0.9852796792984009, val:0.9829351305961609
# LOSS train 0.07548036813162841 valid 0.036684159137318297
# Training vs. Validation Loss {'Training': 0.07548036813162841, 'Validation': 0.036684159137318297} 36
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9829351305961609} 36
# Epoch 36:
# Accuracy train:0.98233562707901, val:0.9863481521606445
# LOSS train 0.0643455834987645 valid 0.02796339082427342
# Training vs. Validation Loss {'Training': 0.0643455834987645, 'Validation': 0.02796339082427342} 37
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9863481521606445} 37
# Epoch 37:
# Accuracy train:0.9901864528656006, val:0.9829351305961609
# LOSS train 0.05161047839702895 valid 0.03370298854315479
# Training vs. Validation Loss {'Training': 0.05161047839702895, 'Validation': 0.03370298854315479} 38
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9829351305961609} 38
# Epoch 38:
# Accuracy train:0.98233562707901, val:0.9829351305961609
# LOSS train 0.0542069968695824 valid 0.04104254048130921
# Training vs. Validation Loss {'Training': 0.0542069968695824, 'Validation': 0.04104254048130921} 39
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9829351305961609} 39
# Epoch 39:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.0467556265111153 valid 0.02393902624256346
# Training vs. Validation Loss {'Training': 0.0467556265111153, 'Validation': 0.02393902624256346} 40
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 40
# Epoch 40:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.05037666645904 valid 0.025160379339164745
# Training vs. Validation Loss {'Training': 0.05037666645904, 'Validation': 0.025160379339164745} 41
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 41
# Epoch 41:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.062106471974402666 valid 0.02408429505400515
# Training vs. Validation Loss {'Training': 0.062106471974402666, 'Validation': 0.02408429505400515} 42
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 42
# Epoch 42:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.04413867646899934 valid 0.028529888658946827
# Training vs. Validation Loss {'Training': 0.04413867646899934, 'Validation': 0.028529888658946827} 43
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 43
# Epoch 43:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.04208581722699679 valid 0.022056416403150553
# Training vs. Validation Loss {'Training': 0.04208581722699679, 'Validation': 0.022056416403150553} 44
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 44
# Epoch 44:
# Accuracy train:0.9892051219940186, val:0.9863481521606445
# LOSS train 0.05141398989452192 valid 0.02206964561143347
# Training vs. Validation Loss {'Training': 0.05141398989452192, 'Validation': 0.02206964561143347} 45
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9863481521606445} 45
# Epoch 45:
# Accuracy train:0.9882237315177917, val:0.9829351305961609
# LOSS train 0.041650010004209786 valid 0.027577692117271606
# Training vs. Validation Loss {'Training': 0.041650010004209786, 'Validation': 0.027577692117271606} 46
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9829351305961609} 46
# Epoch 46:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.03885418200829568 valid 0.02005102934072056
# Training vs. Validation Loss {'Training': 0.03885418200829568, 'Validation': 0.02005102934072056} 47
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 47
# Epoch 47:
# Accuracy train:0.9842983484268188, val:0.9931740760803223
# LOSS train 0.05266508599743247 valid 0.01914731359693178
# Training vs. Validation Loss {'Training': 0.05266508599743247, 'Validation': 0.01914731359693178} 48
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9931740760803223} 48
# Epoch 48:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.0541966797855611 valid 0.027070795018213783
# Training vs. Validation Loss {'Training': 0.0541966797855611, 'Validation': 0.027070795018213783} 49
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 49
# Epoch 49:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.03844513027713849 valid 0.015623692279101912
# Training vs. Validation Loss {'Training': 0.03844513027713849, 'Validation': 0.015623692279101912} 50
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 50
# Epoch 50:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.032735933128816 valid 0.016042762156757817
# Training vs. Validation Loss {'Training': 0.032735933128816, 'Validation': 0.016042762156757817} 51
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 51
# Epoch 51:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.045396188811327405 valid 0.01378783331415434
# Training vs. Validation Loss {'Training': 0.045396188811327405, 'Validation': 0.01378783331415434} 52
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 52
# Epoch 52:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.040053235134109855 valid 0.018318842360561877
# Training vs. Validation Loss {'Training': 0.040053235134109855, 'Validation': 0.018318842360561877} 53
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 53
# Epoch 53:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.055539241956117064 valid 0.02528142468418082
# Training vs. Validation Loss {'Training': 0.055539241956117064, 'Validation': 0.02528142468418082} 54
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 54
# Epoch 54:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.042812540115287095 valid 0.015964097552265837
# Training vs. Validation Loss {'Training': 0.042812540115287095, 'Validation': 0.015964097552265837} 55
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 55
# Epoch 55:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.039261119010356754 valid 0.016296786640547605
# Training vs. Validation Loss {'Training': 0.039261119010356754, 'Validation': 0.016296786640547605} 56
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 56
# Epoch 56:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.03688569827220188 valid 0.014469229707704775
# Training vs. Validation Loss {'Training': 0.03688569827220188, 'Validation': 0.014469229707704775} 57
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 57
# Epoch 57:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.029454742128459308 valid 0.0099604205080747
# Training vs. Validation Loss {'Training': 0.029454742128459308, 'Validation': 0.0099604205080747} 58
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 58
# Epoch 58:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.042962812075319774 valid 0.016857385017222743
# Training vs. Validation Loss {'Training': 0.042962812075319774, 'Validation': 0.016857385017222743} 59
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 59
# Epoch 59:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.037893096038785115 valid 0.010519117507404493
# Training vs. Validation Loss {'Training': 0.037893096038785115, 'Validation': 0.010519117507404493} 60
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 60
# Epoch 60:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.04101457259653566 valid 0.015223835341354667
# Training vs. Validation Loss {'Training': 0.04101457259653566, 'Validation': 0.015223835341354667} 61
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 61
# Epoch 61:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.03548548777157871 valid 0.011321591398882447
# Training vs. Validation Loss {'Training': 0.03548548777157871, 'Validation': 0.011321591398882447} 62
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 62
# Epoch 62:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.03822831381470538 valid 0.02661479064499872
# Training vs. Validation Loss {'Training': 0.03822831381470538, 'Validation': 0.02661479064499872} 63
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 63
# Epoch 63:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.02604098071774038 valid 0.022132913557773765
# Training vs. Validation Loss {'Training': 0.02604098071774038, 'Validation': 0.022132913557773765} 64
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 64
# Epoch 64:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.028178607946476683 valid 0.016956844660550512
# Training vs. Validation Loss {'Training': 0.028178607946476683, 'Validation': 0.016956844660550512} 65
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 65
# Epoch 65:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.0302244912689695 valid 0.01783317195183069
# Training vs. Validation Loss {'Training': 0.0302244912689695, 'Validation': 0.01783317195183069} 66
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 66
# Epoch 66:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.030143370636953756 valid 0.017613718061132506
# Training vs. Validation Loss {'Training': 0.030143370636953756, 'Validation': 0.017613718061132506} 67
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 67
# Epoch 67:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.021581226216557507 valid 0.00962682878753185
# Training vs. Validation Loss {'Training': 0.021581226216557507, 'Validation': 0.00962682878753185} 68
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 68
# Epoch 68:
# Accuracy train:0.9862610697746277, val:0.9965870380401611
# LOSS train 0.024463582443646513 valid 0.008351293827521053
# Training vs. Validation Loss {'Training': 0.024463582443646513, 'Validation': 0.008351293827521053} 69
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9965870380401611} 69
# Epoch 69:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.036087737060510196 valid 0.008134928411247225
# Training vs. Validation Loss {'Training': 0.036087737060510196, 'Validation': 0.008134928411247225} 70
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 70
# Epoch 70:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.027439834809718795 valid 0.010804918365996249
# Training vs. Validation Loss {'Training': 0.027439834809718795, 'Validation': 0.010804918365996249} 71
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 71
# Epoch 71:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.02328249620936381 valid 0.01052424138678513
# Training vs. Validation Loss {'Training': 0.02328249620936381, 'Validation': 0.01052424138678513} 72
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 72
# Epoch 72:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.034683954812443026 valid 0.013348940861002726
# Training vs. Validation Loss {'Training': 0.034683954812443026, 'Validation': 0.013348940861002726} 73
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 73
# Epoch 73:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.039260113737187706 valid 0.01518660010719941
# Training vs. Validation Loss {'Training': 0.039260113737187706, 'Validation': 0.01518660010719941} 74
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 74
# Epoch 74:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.03936447768221395 valid 0.02368732407429282
# Training vs. Validation Loss {'Training': 0.03936447768221395, 'Validation': 0.02368732407429282} 75
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 75
# Epoch 75:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.04166877329295788 valid 0.01877748245336382
# Training vs. Validation Loss {'Training': 0.04166877329295788, 'Validation': 0.01877748245336382} 76
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 76
# Epoch 76:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.02256897179624782 valid 0.017536466527531047
# Training vs. Validation Loss {'Training': 0.02256897179624782, 'Validation': 0.017536466527531047} 77
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 77
# Epoch 77:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.03370963582375015 valid 0.012426135517822937
# Training vs. Validation Loss {'Training': 0.03370963582375015, 'Validation': 0.012426135517822937} 78
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 78
# Epoch 78:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.03541984618641436 valid 0.02273189406059828
# Training vs. Validation Loss {'Training': 0.03541984618641436, 'Validation': 0.02273189406059828} 79
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 79
# Epoch 79:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.031295569004634254 valid 0.01938682834482582
# Training vs. Validation Loss {'Training': 0.031295569004634254, 'Validation': 0.01938682834482582} 80
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 80
# Epoch 80:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.038637177167961806 valid 0.009855016256343182
# Training vs. Validation Loss {'Training': 0.038637177167961806, 'Validation': 0.009855016256343182} 81
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 81
# Epoch 81:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.029938939367779173 valid 0.011087711129107447
# Training vs. Validation Loss {'Training': 0.029938939367779173, 'Validation': 0.011087711129107447} 82
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 82
# Epoch 82:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.023862343536725696 valid 0.009675885761453173
# Training vs. Validation Loss {'Training': 0.023862343536725696, 'Validation': 0.009675885761453173} 83
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 83
# Epoch 83:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.027782568905072715 valid 0.010325342361284129
# Training vs. Validation Loss {'Training': 0.027782568905072715, 'Validation': 0.010325342361284129} 84
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 84
# Epoch 84:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.036752459611027286 valid 0.01540384597103639
# Training vs. Validation Loss {'Training': 0.036752459611027286, 'Validation': 0.01540384597103639} 85
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 85
# Epoch 85:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.035874107673477665 valid 0.00904215896076721
# Training vs. Validation Loss {'Training': 0.035874107673477665, 'Validation': 0.00904215896076721} 86
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 86
# Epoch 86:
# Accuracy train:0.9901864528656006, val:0.9897611141204834
# LOSS train 0.026881366457718495 valid 0.015852453307691878
# Training vs. Validation Loss {'Training': 0.026881366457718495, 'Validation': 0.015852453307691878} 87
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9897611141204834} 87
# Epoch 87:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.032344810284065224 valid 0.013340511699728571
# Training vs. Validation Loss {'Training': 0.032344810284065224, 'Validation': 0.013340511699728571} 88
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 88
# Epoch 88:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.03532782572214133 valid 0.020614461559432584
# Training vs. Validation Loss {'Training': 0.03532782572214133, 'Validation': 0.020614461559432584} 89
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 89
# Epoch 89:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.02391622274612578 valid 0.02197822552462488
# Training vs. Validation Loss {'Training': 0.02391622274612578, 'Validation': 0.02197822552462488} 90
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 90
# Epoch 90:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.028283893829211593 valid 0.022673310799480834
# Training vs. Validation Loss {'Training': 0.028283893829211593, 'Validation': 0.022673310799480834} 91
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 91
# Epoch 91:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.029034124640300155 valid 0.02092096735401583
# Training vs. Validation Loss {'Training': 0.029034124640300155, 'Validation': 0.02092096735401583} 92
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 92
# Epoch 92:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.039412978472403035 valid 0.014281831327404385
# Training vs. Validation Loss {'Training': 0.039412978472403035, 'Validation': 0.014281831327404385} 93
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 93
# Epoch 93:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.02580836715284162 valid 0.011094800199316524
# Training vs. Validation Loss {'Training': 0.02580836715284162, 'Validation': 0.011094800199316524} 94
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 94
# Epoch 94:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.027930783569060553 valid 0.012777326688440857
# Training vs. Validation Loss {'Training': 0.027930783569060553, 'Validation': 0.012777326688440857} 95
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 95
# Epoch 95:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.03574693567889671 valid 0.017257002094993368
# Training vs. Validation Loss {'Training': 0.03574693567889671, 'Validation': 0.017257002094993368} 96
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 96
# Epoch 96:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.02017041283229796 valid 0.00814286305069345
# Training vs. Validation Loss {'Training': 0.02017041283229796, 'Validation': 0.00814286305069345} 97
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 97
# Epoch 97:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.02328119463681315 valid 0.011402942008828632
# Training vs. Validation Loss {'Training': 0.02328119463681315, 'Validation': 0.011402942008828632} 98
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 98
# Epoch 98:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.01998375617236329 valid 0.009684945743705006
# Training vs. Validation Loss {'Training': 0.01998375617236329, 'Validation': 0.009684945743705006} 99
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 99
# Epoch 99:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.023632449715828095 valid 0.012108334540717655
# Training vs. Validation Loss {'Training': 0.023632449715828095, 'Validation': 0.012108334540717655} 100
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 100
# Epoch 100:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.030143417091144677 valid 0.012446279858105905
# Training vs. Validation Loss {'Training': 0.030143417091144677, 'Validation': 0.012446279858105905} 101
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 101
# Epoch 101:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.03216890885064808 valid 0.01712495825682936
# Training vs. Validation Loss {'Training': 0.03216890885064808, 'Validation': 0.01712495825682936} 102
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 102
# Epoch 102:
# Accuracy train:0.9911677837371826, val:0.9897611141204834
# LOSS train 0.01799462670728994 valid 0.018046311845864693
# Training vs. Validation Loss {'Training': 0.01799462670728994, 'Validation': 0.018046311845864693} 103
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9897611141204834} 103
# Epoch 103:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.01977410931767036 valid 0.016165713248151786
# Training vs. Validation Loss {'Training': 0.01977410931767036, 'Validation': 0.016165713248151786} 104
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 104
# Epoch 104:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.03204043727600947 valid 0.02946762779141447
# Training vs. Validation Loss {'Training': 0.03204043727600947, 'Validation': 0.02946762779141447} 105
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 105
# Epoch 105:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.027656268015002403 valid 0.022577118566232457
# Training vs. Validation Loss {'Training': 0.027656268015002403, 'Validation': 0.022577118566232457} 106
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 106
# Epoch 106:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.026501576129633646 valid 0.02925418012951771
# Training vs. Validation Loss {'Training': 0.026501576129633646, 'Validation': 0.02925418012951771} 107
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 107
# Epoch 107:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.028575826516876426 valid 0.020454074846289434
# Training vs. Validation Loss {'Training': 0.028575826516876426, 'Validation': 0.020454074846289434} 108
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 108
# Epoch 108:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.023525204563226838 valid 0.017549141166123643
# Training vs. Validation Loss {'Training': 0.023525204563226838, 'Validation': 0.017549141166123643} 109
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 109
# Epoch 109:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.016583728469693318 valid 0.01687851309940432
# Training vs. Validation Loss {'Training': 0.016583728469693318, 'Validation': 0.01687851309940432} 110
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 110
# Epoch 110:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.024239418271463364 valid 0.01571789273180002
# Training vs. Validation Loss {'Training': 0.024239418271463364, 'Validation': 0.01571789273180002} 111
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 111
# Epoch 111:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.018479483663283575 valid 0.014266126732839743
# Training vs. Validation Loss {'Training': 0.018479483663283575, 'Validation': 0.014266126732839743} 112
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 112
# Epoch 112:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.012939056389418861 valid 0.014817039230393902
# Training vs. Validation Loss {'Training': 0.012939056389418861, 'Validation': 0.014817039230393902} 113
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 113
# Epoch 113:
# Accuracy train:0.9892051219940186, val:0.9897611141204834
# LOSS train 0.02618662641124012 valid 0.019616353111729268
# Training vs. Validation Loss {'Training': 0.02618662641124012, 'Validation': 0.019616353111729268} 114
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9897611141204834} 114
# Epoch 114:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.02229465578476755 valid 0.015577610380186494
# Training vs. Validation Loss {'Training': 0.02229465578476755, 'Validation': 0.015577610380186494} 115
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 115
# Epoch 115:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.021814557625195727 valid 0.01696042124952631
# Training vs. Validation Loss {'Training': 0.021814557625195727, 'Validation': 0.01696042124952631} 116
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 116
# Epoch 116:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.019614974106214225 valid 0.013550039185541133
# Training vs. Validation Loss {'Training': 0.019614974106214225, 'Validation': 0.013550039185541133} 117
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 117
# Epoch 117:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.017635080099213295 valid 0.016700908167403366
# Training vs. Validation Loss {'Training': 0.017635080099213295, 'Validation': 0.016700908167403366} 118
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 118
# Epoch 118:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.015048401703377469 valid 0.012719509345960963
# Training vs. Validation Loss {'Training': 0.015048401703377469, 'Validation': 0.012719509345960963} 119
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 119
# Epoch 119:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.010337405954487622 valid 0.011351071433011839
# Training vs. Validation Loss {'Training': 0.010337405954487622, 'Validation': 0.011351071433011839} 120
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 120
# Epoch 120:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.01909250638877543 valid 0.01336983410236788
# Training vs. Validation Loss {'Training': 0.01909250638877543, 'Validation': 0.01336983410236788} 121
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 121
# Epoch 121:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.017216245975130454 valid 0.02087781913702713
# Training vs. Validation Loss {'Training': 0.017216245975130454, 'Validation': 0.02087781913702713} 122
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 122
# Epoch 122:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.044381133428452395 valid 0.019853492291067216
# Training vs. Validation Loss {'Training': 0.044381133428452395, 'Validation': 0.019853492291067216} 123
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 123
# Epoch 123:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.027986344961950984 valid 0.022019112637394755
# Training vs. Validation Loss {'Training': 0.027986344961950984, 'Validation': 0.022019112637394755} 124
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 124
# Epoch 124:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.01597355957178829 valid 0.015391409080346344
# Training vs. Validation Loss {'Training': 0.01597355957178829, 'Validation': 0.015391409080346344} 125
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 125
# Epoch 125:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.02003953123662191 valid 0.01739325391839941
# Training vs. Validation Loss {'Training': 0.02003953123662191, 'Validation': 0.01739325391839941} 126
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 126
# Epoch 126:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.01595565643107805 valid 0.02608559630760965
# Training vs. Validation Loss {'Training': 0.01595565643107805, 'Validation': 0.02608559630760965} 127
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 127
# Epoch 127:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.01870566886478068 valid 0.01796346307113102
# Training vs. Validation Loss {'Training': 0.01870566886478068, 'Validation': 0.01796346307113102} 128
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 128
# Epoch 128:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.02026834199652792 valid 0.017391900560118263
# Training vs. Validation Loss {'Training': 0.02026834199652792, 'Validation': 0.017391900560118263} 129
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 129
# Epoch 129:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.012283861294585781 valid 0.01694965092560589
# Training vs. Validation Loss {'Training': 0.012283861294585781, 'Validation': 0.01694965092560589} 130
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 130
# Epoch 130:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.013032885286240624 valid 0.012618734743649421
# Training vs. Validation Loss {'Training': 0.013032885286240624, 'Validation': 0.012618734743649421} 131
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 131
# Epoch 131:
# Accuracy train:1.0, val:0.9931740760803223
# LOSS train 0.008233994888052201 valid 0.015616187524396233
# Training vs. Validation Loss {'Training': 0.008233994888052201, 'Validation': 0.015616187524396233} 132
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9931740760803223} 132
# Epoch 132:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.014870679870140381 valid 0.02595876942441085
# Training vs. Validation Loss {'Training': 0.014870679870140381, 'Validation': 0.02595876942441085} 133
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 133
# Epoch 133:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.022928555332607806 valid 0.02052919568852
# Training vs. Validation Loss {'Training': 0.022928555332607806, 'Validation': 0.02052919568852} 134
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 134
# Epoch 134:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.017342228752498228 valid 0.024005960627979068
# Training vs. Validation Loss {'Training': 0.017342228752498228, 'Validation': 0.024005960627979068} 135
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 135
# Epoch 135:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.02573763342829457 valid 0.02180394965081926
# Training vs. Validation Loss {'Training': 0.02573763342829457, 'Validation': 0.02180394965081926} 136
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 136
# Epoch 136:
# Accuracy train:0.9882237315177917, val:0.9863481521606445
# LOSS train 0.030473380060776926 valid 0.026757150826341558
# Training vs. Validation Loss {'Training': 0.030473380060776926, 'Validation': 0.026757150826341558} 137
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9863481521606445} 137
# Epoch 137:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.02679395915206092 valid 0.024959604910539685
# Training vs. Validation Loss {'Training': 0.02679395915206092, 'Validation': 0.024959604910539685} 138
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 138
# Epoch 138:
# Accuracy train:0.9960745573043823, val:0.9863481521606445
# LOSS train 0.01139379394813799 valid 0.03296701371456834
# Training vs. Validation Loss {'Training': 0.01139379394813799, 'Validation': 0.03296701371456834} 139
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9863481521606445} 139
# Epoch 139:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.013715201377635822 valid 0.01788958535202312
# Training vs. Validation Loss {'Training': 0.013715201377635822, 'Validation': 0.01788958535202312} 140
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 140
# Epoch 140:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.015335485996239675 valid 0.020249925916949962
# Training vs. Validation Loss {'Training': 0.015335485996239675, 'Validation': 0.020249925916949962} 141
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 141
# Epoch 141:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.01363965213442078 valid 0.030813869120905224
# Training vs. Validation Loss {'Training': 0.01363965213442078, 'Validation': 0.030813869120905224} 142
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 142
# Epoch 142:
# Accuracy train:0.9950932264328003, val:0.9829351305961609
# LOSS train 0.024641762329758003 valid 0.04522512523734671
# Training vs. Validation Loss {'Training': 0.024641762329758003, 'Validation': 0.04522512523734671} 143
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9829351305961609} 143
# Epoch 143:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.017477195849866033 valid 0.030520602466083346
# Training vs. Validation Loss {'Training': 0.017477195849866033, 'Validation': 0.030520602466083346} 144
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 144
# Epoch 144:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.015713831632568214 valid 0.025399862110293252
# Training vs. Validation Loss {'Training': 0.015713831632568214, 'Validation': 0.025399862110293252} 145
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 145
# Epoch 145:
# Accuracy train:0.9931305050849915, val:0.9829351305961609
# LOSS train 0.020856411160471346 valid 0.039285873696466446
# Training vs. Validation Loss {'Training': 0.020856411160471346, 'Validation': 0.039285873696466446} 146
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9829351305961609} 146
# stopping at epoch 145, minimum: 0.008134928411247225
# tensor(0.9829)

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))

test_loader = torch.utils.data.DataLoader(testset, batch_size=20, shuffle=False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network(test_input)
    acc_test.update(preds, test_label)


print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9724409580230713
# ========================================================================
